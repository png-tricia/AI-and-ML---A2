# %% [markdown]
# Part 6: Consuming Web Service

# %% [markdown]
# Sample.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Explain.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Evaluate.
#
# ![image-2.png](attachment:image-2.png)
#
# Therefore, the customer was dissatsified with their flight.

# %% [markdown]
# ### Test Your Evaluate 5 times with different inputs!

# %% [markdown]
# Evaluation 1:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Evaluation 2:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Evaluation 3:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Evaluation 4:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Evaluation 5:
#
# ![image-2.png](attachment:image-2.png)
